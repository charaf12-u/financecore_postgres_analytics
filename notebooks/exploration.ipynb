# %%
import pandas as pd

df = pd.read_csv("../financecore_clean.csv")

df.head()

df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1925 entries, 0 to 1924
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   transaction_id       1925 non-null   object
#  1   client_id            1925 non-null   object
#  2   date_transaction     1925 non-null   object
#  3   montant              1925 non-null   float64
#  4   devise               1925 non-null   object
#  5   taux_change_eur      1925 non-null   float64
#  6   montant_eur          1925 non-null   float64
#  7   categorie            1925 non-null   object
#  8   produit              1925 non-null   object
#  9   agence               1925 non-null   object
#  10  type_operation       1925 non-null   object
#  11  statut               1925 non-null   object
#  12  score_credit_client  1925 non-null   float64
#  13  segment_client       1925 non-null   object
#  14  solde_avant          1925 non-null   float64
# ...
